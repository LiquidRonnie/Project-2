# %%
# import numpy, pandas for data manipulation
import pandas as pd
import fbprophet
import matplotlib.pyplot as plt

# %%
# import data Fort Pulaski, GA monthly temperature data
weather_data = pd.read_csv('Fort Pulaski, GA.csv')


# weather_data = weather_data.rename(columns={'date':'ds','Monthly_Avg_Temp':'y'})

# %%
# Check Dataset shape
print(weather_data.shape)

# select the data and temperature columns
temp_df = weather_data[['date', 'Monthly_Avg_Temp']]

# rename column
temp_df = temp_df.rename(columns={'date':'ds','Monthly_Avg_Temp':'y'})

temp_df.head(10)
# Out:
# (508, 4)
#         ds     y
# 0   1979-1  45.3
# 1   1979-2  46.8
# 2   1979-3  57.3
# 3   1979-4  64.9
# 4   1979-5  72.4
# 5   1979-6  75.8
# 6   1979-7  81.9
# 7   1979-8  81.4
# 8   1979-9  76.5
# 9  1979-10  65.9

# %%
temp_df['ds'] = pd.to_datetime(temp_df['ds'])
temp_df
# Out:
#             ds     y
# 0   1979-01-01  45.3
# 1   1979-02-01  46.8
# 2   1979-03-01  57.3
# 3   1979-04-01  64.9
# 4   1979-05-01  72.4
# ..         ...   ...
# 503 2021-02-01  50.7
# 504 2021-03-01  51.5
# 505 2021-04-01  60.5
# 506 2021-05-01  65.0
# 507 2021-06-01  71.6
#
# [508 rows x 2 columns]

# %%
# select the subset datea from 2015 - 2019
# mask = (temp_df['ds'] >= '2018-01-01') & (temp_df['ds'] <= '2021-05-04')
# temp_df = temp_df.loc[mask]

# iunpect first 5 rows and loast 5 rows of the data
from IPython.display import display
display(temp_df.head(5))
display(temp_df.tail(5))
# Out:
#           ds     y
# 0 1979-01-01  45.3
# 1 1979-02-01  46.8
# 2 1979-03-01  57.3
# 3 1979-04-01  64.9
# 4 1979-05-01  72.4
#             ds     y
# 503 2021-02-01  50.7
# 504 2021-03-01  51.5
# 505 2021-04-01  60.5
# 506 2021-05-01  65.0
# 507 2021-06-01  71.6

# %%
# describe
temp_df.describe()
# Out:
#                 y
# count  508.000000
# mean    66.275591
# std     11.995079
# min     42.600000
# 25%     55.475000
# 50%     66.000000
# 75%     78.150000
# max     86.200000

# %%
# Output the max and min temps
print(temp_df.loc[temp_df['y'] == temp_df['y'].max()])
print(temp_df.loc[temp_df['y'] == temp_df['y'].min()])
# Out:
#             ds     y
# 448 2016-07-01  86.2
#             ds     y
# 72  1985-01-01  42.6
# 263 2000-12-01  42.6

# %%
# plot the daily temperature change
plt.figure(figsize=(16,10), dpi=100)
plt.plot(temp_df.index, temp_df.y, color='tab:red')
plt.gca().set(title='Daily Temperaure from 2018-2021', xlabel='Date', ylabel='Degree(in Farenhait)')
plt.show()

# %%
# import Prophet
from fbprophet import Prophet

# %%
# Initialize Model
m = Prophet()
m.fit(temp_df)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# KeyError: 'metric_file'

# %%
m.fit(temp_df)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# KeyError: 'metric_file'
# Exception ignored in: 'stanfit4anon_model_f5236004a3fd5b8429270d00efcc0cf9_9045703871880297330._set_stanargs_from_dict'
# Traceback (most recent call last):
#   File "C:\Users\Ronca\anaconda3\lib\site-packages\pystan\model.py", line 550, in optimizing
#     ret, sample = fit._call_sampler(stan_args)
# KeyError: 'metric_file'
